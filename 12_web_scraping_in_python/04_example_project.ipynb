# %% [markdown]
# -----
#
# # **`Python For Beginners`**
#
# ## **Author: Muhammad Adil Naeem**
# ## **Contact Me: `madilnaeem@gmail.com`**
#
#
# ------

# %% [markdown]
# ![c27.PNG](attachment:c27.PNG)

# %% [markdown]
# ![c28.PNG](attachment:c28.PNG)

# %% [markdown]
# ![c29.PNG](attachment:c29.PNG)

# %% [markdown]
# ##### **Import Required Libraries**

# %%
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# ##### **Url for Web scrapping**

# %%
url = "https://www.simplilearn.com/"

# %% [markdown]
# ##### **View html strructure**

# %%
# Access the url with request object
result = requests.get(url)

# Scrape the web ppage content
page_content = result.content

# Create soup object
soup = BeautifulSoup(page_content, "html.parser")

# %%
# Close the result object
result.close()

# View the content of soup object
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en-US" xmlns="https://www.w3.org/1999/xhtml">
#  <head>
#   <script crossorigin="" fetchpriority="high" rel="preload" src="https://unpkg.com/react@18.2.0/umd/react.production.min.js">
#   </script>
#   <script crossorigin="" fetchpriority="high" rel="preload" src="https://unpkg.com/react-dom@18.2.0/umd/react-dom.production.min.js">
#   </script>
#   <script crossorigin="" fetchpriority="high" rel="preload" src="https://cdnjs.cloudflare.com/ajax/libs/redux/4.2.1/redux.min.js">
#   </script>
#   <script crossorigin="" fetchpriority="high" rel="preload" src="https://cdn.jsdelivr.net/npm/react-redux@8.0.5/dist/react-redux.min.js">
#   </script>
#   <!-- Global site tag (gtag.js) - Google Analytics 4 -->
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-CG9EYRX7VL">
#   </script>
#   <script>
#    window.dataLayer = window.dataLayer || [];
#       function gtag(){dataLayer.push(arguments);}
#       gtag('js', new Date());
#
# ...

# %%
# View the head of the soup object
soup.head
# Out:
# <head>
# <script crossorigin="" fetchpriority="high" rel="preload" src="https://unpkg.com/react@18.2.0/umd/react.production.min.js"> </script>
# <script crossorigin="" fetchpriority="high" rel="preload" src="https://unpkg.com/react-dom@18.2.0/umd/react-dom.production.min.js"> </script>
# <script crossorigin="" fetchpriority="high" rel="preload" src="https://cdnjs.cloudflare.com/ajax/libs/redux/4.2.1/redux.min.js"> </script>
# <script crossorigin="" fetchpriority="high" rel="preload" src="https://cdn.jsdelivr.net/npm/react-redux@8.0.5/dist/react-redux.min.js"> </script>
# <!-- Global site tag (gtag.js) - Google Analytics 4 -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-CG9EYRX7VL"></script>
# <script>
#       window.dataLayer = window.dataLayer || [];
#       function gtag(){dataLayer.push(arguments);}
#       gtag('js', new Date());
#
#       gtag('config', 'G-CG9EYRX7VL', {"site_speed_sample_rate":20,"transport_type":"beacon"});
# ...

# %%
# view the title of the page
soup.title
# Out:
# <title>Simplilearn | Online Courses - Bootcamp &amp; Certification Platform</title>

# %% [markdown]
# ##### **Find all links on the page**

# %%
for href in soup.find_all('a',href=True):
  print(href.get('href'))
# Out:
# https://www.simplilearn.com/resources
# https://www.simplilearn.com/business
# https://www.simplilearn.com/become-our-trainer
# https://www.simplilearn.com/reseller-partner-program-for-training-courses
# https://www.simplilearn.com/reviews
# https://www.simplilearn.com
# https://www.simplilearn.com/reviews
# https://www.simplilearn.com/business
# https://www.simplilearn.com/resources
# #
# https://www.simplilearn.com/reseller-partner-program-for-training-courses
# https://www.simplilearn.com/become-our-trainer
#
# #our-programs
# https://www.simplilearn.com/certifications/generative-ai-courses
# business/learning-hub-plus
#
# /project-management/pmp-certification-training
# /artificial-intelligence-masters-program-training-course
# /business-analyst-certification-training-course
# /data-analyst-masters-certification-training-course
# /agile-and-scrum/csm-certification-training
# /it-service-management/itil-foundation-training
# ...
