# %% [markdown]
# -----
#
# # **`Python For Beginners`**
#
# ## **Author: Muhammad Adil Naeem**
# ## **Contact Me: `madilnaeem@gmail.com`**
#
#
# ------

# %% [markdown]
# ![a10.PNG](attachment:a10.PNG)

# %% [markdown]
# ![a11.PNG](attachment:a11.PNG)

# %% [markdown]
# ![a12.PNG](attachment:a12.PNG)

# %% [markdown]
# ### **`Pandas in Python`**

# %%
import pandas as pd
import numpy as np
import random

# %%
# Create a DataFrame
df = pd.DataFrame(np.random.randn(6, 4), index=list(range(0, 6)), columns=list('ABCD'))
df
# Out:
#           A         B         C         D
# 0 -0.580115 -0.602185  0.724830 -0.889056
# 1 -0.702343 -1.303600  0.613663  0.016286
# 2 -0.032471  1.864316  0.751003  0.972175
# 3  1.680469  1.829650  1.594184 -0.817421
# 4  0.235610 -0.268247 -0.413942 -0.255443
# 5 -0.421913 -0.432262  0.837085  0.336560

# %%
# Check information of dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       6 non-null      float64
#  1   B       6 non-null      float64
#  2   C       6 non-null      float64
#  3   D       6 non-null      float64
# dtypes: float64(4)
# memory usage: 240.0 bytes

# %%
# Check statistical description of dataframe
df.describe()
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean   0.029873  0.181279  0.684471 -0.106150
# std    0.881251  1.337679  0.643187  0.709211
# min   -0.702343 -1.303600 -0.413942 -0.889056
# 25%   -0.540564 -0.559705  0.641455 -0.676926
# 50%   -0.227192 -0.350254  0.737917 -0.119579
# 75%    0.168590  1.305176  0.815564  0.256492
# max    1.680469  1.864316  1.594184  0.972175
