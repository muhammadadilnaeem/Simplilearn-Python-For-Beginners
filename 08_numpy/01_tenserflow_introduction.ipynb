# %% [markdown]
# -----
#
# # **`Python For Beginners`**
#
# ## **Author: Muhammad Adil Naeem**
# ## **Contact Me: `madilnaeem@gmail.com`**
#
#
# ------

# %% [markdown]
# ### **`Tenserflow in Python`**

# %% [markdown]
# ![a1.PNG](data:image/png;base64,...)

# %% [markdown]
# ![a2.PNG](data:image/png;base64,...)

# %% [markdown]
# ![a3.PNG](data:image/png;base64,...)

# %% [markdown]
# ### **`MNIST Handwriten Digit Recognition`**
#
# - This dataset has 55k training Images.
# - 10K Test Images.
# - 5k Validation Images
