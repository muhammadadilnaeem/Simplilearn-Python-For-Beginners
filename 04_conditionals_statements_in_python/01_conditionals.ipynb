# %% [markdown]
# -----
#
# # **`Python For Beginners`**
#
# ## **Author: Muhammad Adil Naeem**
# ## **Contact Me: `madilnaeem@gmail.com`**
#
#
# ------

# %% [markdown]
# ![c1.PNG](attachment:c1.PNG)

# %% [markdown]
# -----
#
# ## **`Python Conditionals Statements`**

# %%
a = 50

if a >= 50:
  print("Accepted")
print("You are Welcome!")
# Out:
# Accepted
# You are Welcome!

# %% [markdown]
# ![c2.PNG](attachment:c2.PNG)

# %%
i = 20

if i % 2 == 0:
    print("This is an If block.")
    print("'i' is an Even number.")
else:
    print("This is an else block.")
    print("'i' is an Odd number.")
# Out:
# This is an If block.
# 'i' an Even number.

# %% [markdown]
# -----
#
# ![c3.PNG](attachment:c3.PNG)
#
#
# -----

# %%
c = 25
if c < 25:
    if c % 2 == 0:
        print("This is an If if block.")
        print("'c' is an Even number.")
    else:
        print("This is an if else block.")
        print("'c' is an Odd number.")
else:
    print("This is an else else block.")
    print("'c' is greater than or equal to 25.")
# Out:
# This is an else else block.
# 'c' is greater than or equal to 25.
